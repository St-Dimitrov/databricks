# %% [markdown]
# - Ingestion method is batch over DBFS, archving file after timestamping ingestion datetime
# - Bronza layer schema is not manually defined. This is NOT recomended for production env. Raw data appends to table with timestamp
# - Silver layer schema is defined. Bronze data is transformed before being merged or inserted if not matched.
# - Gold layer export to PowerBI ready
